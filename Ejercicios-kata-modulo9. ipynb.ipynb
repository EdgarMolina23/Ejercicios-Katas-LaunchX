# %%
# Función para leer 3 tanques de combustible y muestre el promedio

def generar_reporte(principal, externo, hidrogeno):
    promedio_general = (principal + externo + hidrogeno) / 3
    return f"""Fuel Report:
    Total Average: {promedio_general}%
    Main tank: {principal}%
    External tank: {externo}%
    Hydrogen tank: {hidrogeno}% 
    """
# Llamamos a la función que genera el reporte print(funcion(tanque1, tanque2, tanque3))
print(generar_reporte(80, 70, 85))

# Función promedio 
def average(values):
    total = sum(values)
    number_of_items = len(values)
    return total / number_of_items

# Test the averaging function with a list of integers:
average([80, 85, 81]) 
# Actualiza la función
def generar_reporte(principal, externo, hidrogeno):
    return f"""Fuel Report:
    Total Average: {average([principal, externo, hidrogeno])}%
    Main tank: {principal}%
    External tank: {externo}%
    Hydrogen tank: {hidrogeno}% 
    """

# Llamar a la funcion con diferentes datos
print(generar_reporte(88, 76, 70))

# Función con un informe preciso de la misión. Considera hora de prelanzamiento, tiempo de vuelo, destino, tanque externo y tanque interno

def reporte_mision(tiempo_prelanzamiento, tiempo_vuelo, destino, tanque_externo, tanque_principal):
    return f"""
    Mission to {destino}
    Total travel time: {tiempo_prelanzamiento + tiempo_vuelo} minutes
    Total fuel left: {tanque_externo + tanque_principal} gallons
    """

print(reporte_mision(14, 51, "Moon", 200000, 300000))

# Escribe tu nueva función de reporte considerando lo anterior

def reporte_mision(destino, *minutes, **fuel_reservoirs):
    return f"""
    Mission to {destino}
    Total travel time: {sum(minutes)} minutes
    Total fuel left: {sum(fuel_reservoirs.values())}
    """

print(reporte_mision("Moon", 10, 15, 51, main=300000, external=200000))
# Escribe tu nueva función

def reporte_mision(destino, *minutes, **fuel_reservoirs):
    main_report = f"""
    Mission to {destino}
    Total travel time: {sum(minutes)} minutes
    Total fuel left: {sum(fuel_reservoirs.values())}
    """
    for tank_name, gallons in fuel_reservoirs.items():
        main_report += f"{tank_name} tank --> {gallons} gallons left\n"
    return main_report

print(reporte_mision("Moon", 8, 11, 55, main=300000, external=200000))
# Out:
# Fuel Report:
#     Total Average: 78.33333333333333%
#     Main tank: 80%
#     External tank: 70%
#     Hydrogen tank: 85%
#
# Fuel Report:
#     Total Average: 78.0%
#     Main tank: 88%
#     External tank: 76%
#     Hydrogen tank: 70%
#
#
#     Mission to Moon
#     Total travel time: 65 minutes
#     Total fuel left: 500000 gallons
#
#
#     Mission to Moon
#     Total travel time: 76 minutes
#     Total fuel left: 500000
#
#
#     Mission to Moon
#     Total travel time: 74 minutes
#     Total fuel left: 500000
#     main tank --> 300000 gallons left
# external tank --> 200000 gallons left
